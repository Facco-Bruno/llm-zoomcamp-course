# %%
# !pip install fastmcp
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 9.7 MB/s eta 0:00:00
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11103 sha256=3ebd574da0a313bb8dc2e3684426211014a6e507aa2f03a5166819c19a89750b
#   Stored in directory: /home/codespace/.cache/pip/wheels/e0/e8/fc/8ab8aa326e33bc066ccd5f3ca9646eab4299881af933f94f09
# Successfully built pyperclip
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.5
#     Uninstalling pydantic-2.11.5:
#       Successfully uninstalled pydantic-2.11.5
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import fastmcp
print(fastmcp.__version__)
# Out:
# 2.10.5
